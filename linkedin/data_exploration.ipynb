# %%
import pandas as pd
file = pd.read_csv('data_Top_titles_For_All_Industry_Updated_100k.csv', names=['Title', 'Counts'])

# %%
file
# Out:
#                  Title  Counts
# 0                  NaN    1837
# 1                    `      95
# 2                    ~     400
# 3                   ~~      44
# 4                    =      91
# 5                    >      48
# 6                    |      64
# 7                    _    1870
# 8                   __     365
# 9                  ___     206
# 10                ____      90
# 11               _____      63
# 12              ______      39
# 13           ¯\_(ツ)_/¯      44
# 14                   -    8622
# 15                 - -     179
# 16                  --    1439
# 17                 ---     770
# 18                ----     918
# 19               -----     546
# 20              ------     362
# 21             -------     234
# 22            --------     204
# 23           ---------     149
# 24          ----------     113
# 25         -----------     100
# 26        ------------      90
# 27       -------------      67
# 28      --------------      54
# ...

# %%
file_sorted = file.sort_values(by = 'Counts', ascending=False)
top100_titles = file_sorted[:100]
top200_titles = file_sorted[:200]

# %%
from IPython.display import display, HTML

display(HTML(top200_titles.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Title</th>
#       <th>Counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>61143</th>
#       <td>Owner</td>
#       <td>1994557</td>
#     </tr>
#     <tr>
#       <th>89678</th>
#       <td>Student</td>
#       <td>1258307</td>
#     </tr>
#     <tr>
#       <th>25634</th>
#       <td>Director</td>
#       <td>610768</td>
#     </tr>
#     <tr>
#       <th>65814</th>
#       <td>President</td>
#       <td>609685</td>
#     </tr>
#     <tr>
#       <th>52199</th>
#       <td>Manager</td>
#       <td>506418</td>
#     </tr>
#     <tr>
#       <th>91782</th>
#       <td>Teacher</td>
#       <td>430131</td>
#     </tr>
#     <tr>
#       <th>74716</th>
#       <td>Retired</td>
#       <td>416271</td>
#     </tr>
#     <tr>
#       <th>69309</th>
#       <td>Project Manager</td>
#       <td>393630</td>
#     </tr>
#     <tr>
#       <th>13831</th>
# ...

# %%
top200_titles.shape
# Out:
# (200, 2)

# %%
top200_titles.to_csv('top200.csv', index=None, header=True)
